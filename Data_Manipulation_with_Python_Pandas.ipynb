# %%
import pandas as pd

# %%
#inporting excel file
df=pd.read_csv('Screen Time Data.csv') # df=pd.read_excel('file neame.xlsx')

# %%
df
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
#show first 5 rows
df.head()
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0
# ...

# %%
#show last 5 rows
df.tail()
# Out:
#     index      Date  Week Day  Total Screen Time   Social Networking  \
# 23     23  05/10/19    Friday                 161                 93
# 24     24  05/11/19  Saturday                  58                 49
# 25     25  05/12/19    Sunday                  52                 28
# 26     26  05/13/19    Monday                  61                 37
# 27     27  05/14/19   Tuesday                  88                 41
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 23                     13     17            16                   1
# 24                      1      2             2                   0
# 25                      1      1             6                   0
# 26                      1      0             4                   0
# 27                      2      7            15                   0
#
#     Entertainment  Creativity  Yoga
# 23              0           0     1
# 24              0           2     1
# ...

# %%
# if i want to show first 10 rows 
df.head(10)
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
# 5      5  04/22/19     Monday                 189                 68
# 6      6  04/23/19    Tuesday                 158                 56
# 7      7  04/24/19  Wednesday                 135                 98
# 8      8  04/25/19   Thursday                  52                 25
# 9      9  04/26/19     Friday                 198                 76
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# ...

# %%
# print the values of df 
df.values
# Out:
# array([[0, '04/17/19', 'Wednesday', 187, 89, 17, 41, 22, 0, 0, 0, 0],
#        [1, '04/18/19', 'Thursday', 123, 78, 17, 8, 9, 0, 0, 0, 0],
#        [2, '04/19/19', 'Friday', 112, 52, 40, 8, 4, 0, 3, 0, 0],
#        [3, '04/20/19', 'Saturday', 101, 69, 9, 38, 2, 0, 3, 0, 0],
#        [4, '04/21/19', 'Sunday', 56, 35, 2, 43, 3, 0, 1, 1, 0],
#        [5, '04/22/19', 'Monday', 189, 68, 0, 9, 3, 4, 0, 0, 0],
#        [6, '04/23/19', 'Tuesday', 158, 56, 18, 41, 12, 15, 0, 0, 0],
#        [7, '04/24/19', 'Wednesday', 135, 98, 3, 33, 16, 0, 0, 0, 0],
#        [8, '04/25/19', 'Thursday', 52, 25, 7, 3, 16, 0, 0, 0, 0],
#        [9, '04/26/19', 'Friday', 198, 76, 8, 29, 15, 0, 32, 0, 0],
#        [10, '04/27/19', 'Saturday', 116, 75, 10, 20, 5, 0, 0, 0, 0],
#        [11, '04/28/19', 'Sunday', 85, 42, 22, 4, 2, 0, 0, 0, 0],
#        [12, '04/29/19', 'Monday', 109, 46, 8, 13, 9, 15, 1, 0, 1],
#        [13, '04/30/19', 'Tuesday', 79, 40, 2, 9, 12, 0, 0, 0, 1],
# ...

# %%
#print the column index of df 
df.columns
# Out:
# Index(['index', 'Date', 'Week Day', 'Total Screen Time ', 'Social Networking',
#        'Reading and Reference', 'Other', 'Productivity', 'Health and Fitness',
#        'Entertainment', 'Creativity', 'Yoga'],
#       dtype='object')

# %%
#print the row index of df
df.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
#specific_column
df.Date
# Out:
# 0     04/17/19
# 1     04/18/19
# 2     04/19/19
# 3     04/20/19
# 4     04/21/19
# 5     04/22/19
# 6     04/23/19
# 7     04/24/19
# 8     04/25/19
# 9     04/26/19
# 10    04/27/19
# 11    04/28/19
# 12    04/29/19
# 13    04/30/19
# 14    05/01/19
# 15    05/02/19
# 16    05/03/19
# 17    05/04/19
# 18    05/05/19
# 19    05/06/19
# 20    05/07/19
# 21    05/08/19
# 22    05/09/19
# 23    05/10/19
# 24    05/11/19
# 25    05/12/19
# 26    05/13/19
# 27    05/14/19
# Name: Date, dtype: object

# %%
# if a column name with space  exist then use ' ' 
df['Social Networking']
# Out:
# 0      89
# 1      78
# 2      52
# 3      69
# 4      35
# 5      68
# 6      56
# 7      98
# 8      25
# 9      76
# 10     75
# 11     42
# 12     46
# 13     40
# 14     90
# 15     60
# 16     64
# 17     34
# 18    109
# 19     81
# 20     70
# 21     53
# 22     42
# 23     93
# 24     49
# 25     28
# 26     37
# 27     41
# Name: Social Networking, dtype: int64

# %%
# if a column name with space  exist then use ' ' 
df[['Social Networking']]
# Out:
#     Social Networking
# 0                  89
# 1                  78
# 2                  52
# 3                  69
# 4                  35
# 5                  68
# 6                  56
# 7                  98
# 8                  25
# 9                  76
# 10                 75
# 11                 42
# 12                 46
# 13                 40
# 14                 90
# 15                 60
# 16                 64
# 17                 34
# 18                109
# 19                 81
# 20                 70
# 21                 53
# 22                 42
# 23                 93
# 24                 49
# 25                 28
# 26                 37
# 27                 41

# %%
#specific column show specific number of element show 
df.Date.head(6)
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# 4    04/21/19
# 5    04/22/19
# Name: Date, dtype: object

# %%
df['Date'].head()
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# 4    04/21/19
# Name: Date, dtype: object

# %%
#specific more than one column show or multiple column show 
df[['Date','Week Day']].head()
# Out:
#        Date   Week Day
# 0  04/17/19  Wednesday
# 1  04/18/19   Thursday
# 2  04/19/19     Friday
# 3  04/20/19   Saturday
# 4  04/21/19     Sunday

# %%
#assending order
df['Social Networking'].sort_values() #shift+tab
# Out:
# 8      25
# 25     28
# 17     34
# 4      35
# 26     37
# 13     40
# 27     41
# 11     42
# 22     42
# 12     46
# 24     49
# 2      52
# 21     53
# 6      56
# 15     60
# 16     64
# 5      68
# 3      69
# 20     70
# 10     75
# 9      76
# 1      78
# 19     81
# 0      89
# 14     90
# 23     93
# 7      98
# 18    109
# Name: Social Networking, dtype: int64

# %%
#decending order
df['Social Networking'].sort_values(ascending=False) #shift+tab
# Out:
# 18    109
# 7      98
# 23     93
# 14     90
# 0      89
# 19     81
# 1      78
# 9      76
# 10     75
# 20     70
# 3      69
# 5      68
# 16     64
# 15     60
# 6      56
# 21     53
# 2      52
# 24     49
# 12     46
# 11     42
# 22     42
# 27     41
# 13     40
# 26     37
# 4      35
# 17     34
# 25     28
# 8      25
# Name: Social Networking, dtype: int64

# %%
#full dataframe sort based on 'Social Networking'
df.sort_values('Social Networking',ascending=False)
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 18     18  05/05/19     Sunday                 133                109
# 7       7  04/24/19  Wednesday                 135                 98
# 23     23  05/10/19     Friday                 161                 93
# 14     14  05/01/19  Wednesday                 127                 90
# 0       0  04/17/19  Wednesday                 187                 89
# 19     19  05/06/19     Monday                 144                 81
# 1       1  04/18/19   Thursday                 123                 78
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 20     20  05/07/19    Tuesday                 110                 70
# 3       3  04/20/19   Saturday                 101                 69
# 5       5  04/22/19     Monday                 189                 68
# ...

# %%
#Statistical Analysis
df.describe()
# Out:
#            index  Total Screen Time   Social Networking  \
# count  28.000000           28.000000          28.000000
# mean   13.500000          113.250000          60.714286
# std     8.225975           43.562322          22.853571
# min     0.000000           52.000000          25.000000
# 25%     6.750000           83.500000          41.750000
# 50%    13.500000          111.000000          58.000000
# 75%    20.250000          137.250000          76.500000
# max    27.000000          198.000000         109.000000
#
#        Reading and Reference      Other  Productivity  Health and Fitness  \
# count              28.000000  28.000000     28.000000           28.000000
# mean                8.714286  14.821429      9.071429            1.285714
# std                 9.340700  13.754605      6.097532            3.952094
# min                 0.000000   0.000000      2.000000            0.000000
# 25%                 2.000000   4.750000      3.000000            0.000000
# ...

# %%
#subseting rows 
df['Social Networking'] > 50
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# Name: Social Networking, dtype: bool

# %%
#show better and details with data frame 
df[df['Social Networking'] >50]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 14     14  05/01/19  Wednesday                 127                 90
# 15     15  05/02/19   Thursday                 170                 60
# 16     16  05/03/19     Friday                  91                 64
# ...

# %%
#subseting rows with string values
df[df['Week Day']=='Wednesday']
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 7       7  04/24/19  Wednesday                 135                 98
# 14     14  05/01/19  Wednesday                 127                 90
# 21     21  05/08/19  Wednesday                 122                 53
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 7                       3     33            16                   0
# 14                      0     10             7                   0
# 21                     25     26            15                   0
#
#     Entertainment  Creativity  Yoga
# 0               0           0     0
# 7               0           0     0
# 14              0           0     1
# 21              0           0     1

# %%
#subseting rows with more than one condition 
df[(df['Week Day']=='Wednesday') | (df['Week Day']=='Sunday')]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 4       4  04/21/19     Sunday                  56                 35
# 7       7  04/24/19  Wednesday                 135                 98
# 11     11  04/28/19     Sunday                  85                 42
# 14     14  05/01/19  Wednesday                 127                 90
# 18     18  05/05/19     Sunday                 133                109
# 21     21  05/08/19  Wednesday                 122                 53
# 25     25  05/12/19     Sunday                  52                 28
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 4                       2     43             3                   0
# 7                       3     33            16                   0
# ...

# %%
# Subsetting using isin()
df['Week Day'].isin(['Wednesday','Sunday'])
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# Name: Week Day, dtype: bool

# %%
# Subsetting using isin()
df[df['Week Day'].isin(['Wednesday','Sunday'])]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 4       4  04/21/19     Sunday                  56                 35
# 7       7  04/24/19  Wednesday                 135                 98
# 11     11  04/28/19     Sunday                  85                 42
# 14     14  05/01/19  Wednesday                 127                 90
# 18     18  05/05/19     Sunday                 133                109
# 21     21  05/08/19  Wednesday                 122                 53
# 25     25  05/12/19     Sunday                  52                 28
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 4                       2     43             3                   0
# 7                       3     33            16                   0
# ...
